# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
import cv2
from glob import glob
from skimage.io import imread, imshow
import piexif

# %%
import os

# %%
# using os sets the \ for me
basepath = os.path.join('..', 'train\\')

# %%
print(basepath)
# Out:
# ..\train\

# %%
all_cervix_images = []

# %%
for path in sorted(glob(basepath + "*")):
    # escape \
    cervix_type = path.split("\\")[-1]
    cervix_images = sorted((glob(basepath + cervix_type + "/*")))
    all_cervix_images = all_cervix_images + cervix_images

# %%
all_cervix_images = pd.DataFrame({'imagepath': all_cervix_images})
all_cervix_images['filetype'] = all_cervix_images.apply(lambda row: row.imagepath.split(".")[-1], axis=1)
all_cervix_images['type'] = all_cervix_images.apply(lambda row: row.imagepath.split("\\")[-2], axis=1)

# %%
all_cervix_images.head()
# Out:
#                   imagepath filetype    type
# 0     ..\train\Type_1\0.jpg      jpg  Type_1
# 1    ..\train\Type_1\10.jpg      jpg  Type_1
# 2  ..\train\Type_1\1013.jpg      jpg  Type_1
# 3  ..\train\Type_1\1014.jpg      jpg  Type_1
# 4  ..\train\Type_1\1019.jpg      jpg  Type_1

# %%
from scipy import ndimage, misc

# %%
print('We have a total of {} images in the whole dataset'.format(all_cervix_images.shape[0]))
# Out:
# We have a total of 1480 images in the whole dataset

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.set_title('Cervix Types in Dataset')
sns.countplot(y='type',data=all_cervix_images, ax=ax)

# %%
print('Percantage of each type in the data:')
for c_type in ['Type_1', 'Type_2', 'Type_3']:
    print(c_type + ': ' + '{:.1f} %'.format(
        len(all_cervix_images[all_cervix_images.type == c_type]) / len(all_cervix_images) * 100)
         )
# Out:
# Percantage of each type in the data:
# Type_1: 16.8 %
# Type_2: 52.8 %
# Type_3: 30.4 %

# %%
# fig = plt.figure(figsize=(12,8))

# i = 1
# for t in all_cervix_images['type'].unique():
#     ax = fig.add_subplot(1,3,i)
#     i+=1
#     f = all_cervix_images[all_cervix_images['type'] == t]['imagepath'].values[0]
#     plt.imshow(plt.imread(f))
#     plt.title('sample for cervix {}'.format(t))

# %%
sampled = all_cervix_images.sample(n=200, random_state=42)

# %%
dimensions = []

# %%
# %%time
for i in range(len(sampled)):
    dimensions.append(imread(sampled['imagepath'].iloc[i]).shape)
    if i % 50 == 0:
        print('ok')
# Out:
# ok
# ok
# ok
# ok
# Wall time: 2min 33s

# %%
from collections import Counter

# %%
Counter(dimensions)
# Out:
# Counter({(2448, 3264, 3): 3,
#          (3264, 2448, 3): 110,
#          (4128, 2322, 3): 2,
#          (4128, 3096, 3): 83,
#          (4160, 3120, 3): 2})

# %%
# %%time
images = []
for i in range(len(sampled)):
    image = ndimage.imread(all_cervix_images['imagepath'].iloc[i], mode='RGB')
    image_resized = misc.imresize(image, (640, 640))
    images.append(image_resized)
    if i % 50 == 0:
        print('..', i)
# Out:
# .. 0
# .. 50
# .. 100
# .. 150
# Wall time: 3min 25s

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_image
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(images, sampled['type'], test_size=0.25, random_state=42)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)

# %%
X_train = X_train.reshape(X_train.shape[0], 640, 640, 3)
X_test = X_test.reshape(X_test.shape[0], 640, 640, 3)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True)

datagen.fit(X_train)

for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i])
        
    break

# %%
datagen2 = ImageDataGenerator(featurewise_center=False, featurewise_std_normalization=False, zca_whitening=False)

datagen2.fit(X_train)

for X_batch, y_batch in datagen2.flow(X_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i])
        
    break

# %%
datagen3 = ImageDataGenerator(featurewise_center=False, featurewise_std_normalization=False,
rotation_range=90)

datagen3.fit(X_train)

for X_batch, y_batch in datagen3.flow(X_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i])
        
    break
